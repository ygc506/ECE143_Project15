# %% [markdown]
# # In this .ipnb, we automatically traverse the data table showing the overall death cause ranking system across 51 states based on gender, age.

# %% [markdown]
# ##  1. Import required packages

# %%
import requests
import json
from bs4 import BeautifulSoup
import pandas as pd
from collections import defaultdict
from pandas import ExcelWriter

# %% [markdown]
# ## 2. State Name List

# %%
def state_list():
    '''
    rtype: dict{state name: state index} 
    
    this function finds out all states plus the US itself name and index from website
    '''
    url = "https://www.worldlifeexpectancy.com/usa-cause-of-death-by-age-and-gender"
    response = requests.get(url) 
    soup = BeautifulSoup(response.text, "html.parser") 
    s_list = soup.find_all("div",class_="scrolling-content-wrapper")

    state_list , state_index= {},0
    for i in s_list[0].find_all('a'):
        print
        state_list[i.text] = str(state_index) if state_index!=0 else ''
        state_index+=1
    #print(state_list)
    
    return state_list

# %%
state_list=state_list()

# %% [markdown]
# ## 3. Collect Data according to state and gender

# %%
'''
Given state name and index, this cell can change url accordingly
Save the dataframe into .csv file
'''
gender =['female','male','both']

index = 0
for region, _ in state_list.items():
    writer = pd.ExcelWriter(f'data/newStates/{region}.xlsx')
    state='' if region=='United States' else str(index)
    
    for g in gender:
        # change url to the table we want to collect data now
        url = 'https://www.worldlifeexpectancy.com/j/state-gbd-cause-age?sel=d_35_44&sex={}&state={}'.format(g,state)  
        response = requests.get(url)
        html_doc = response.content 
        json_parsed = json.loads(html_doc)
        
        
        # avoid missing number in url, check whether url exists
        while (json_parsed['chart']['countries']['countryitem'])==[]:
            index+=1
            state='' if region=='United States' else str(index)
            url = 'https://www.worldlifeexpectancy.com/j/state-gbd-cause-age?sel=d_35_44&sex={}&state={}'.format(g,state)  
            response = requests.get(url)
            html_doc = response.content 
            json_parsed = json.loads(html_doc)
        
        # put data into container
        data=defaultdict(list)
        for i in json_parsed['chart']['countries']['countryitem']:
            for j in i.keys():
                tmp = i[j].replace(',','')
                if tmp.isdigit():
                    tmp=int(tmp)
                data[j].append(tmp)

        
        data_contain ={'name': data['name'], 'rank': data['r_d'], 'death': data['d'], 'rank_0_14': data['r_d_0_14'], 'death_0_14':data['d_0_14'], 'rank_15_24': data['r_d_15_24'],
                       'death_15_24': data['d_15_24'], 'rank_25_34': data['r_d_25_34'], 'death_25_34': data['d_25_34'], 'rank_35_44': data['r_d_35_44'], 'death_35_44': data['d_35_44'], 
                       'rank_45_54': data['r_d_45_54'],'death_45_54': data['d_45_54'], 'rank_55_64': data['r_d_55_64'], 'death_55_64': data['d_55_64'], 'rank_65_74': data['r_d_65_74'], 
                       'death_65_74': data['d_65_74'], 'rank_75': data['r_d_75'], 'death_75': data['d_75']}
        
        # change format to panda Dataframe
        frame = pd.DataFrame(data_contain)  

        
        # write into file
        frame.to_excel(writer, sheet_name=g, index=False,engine='openpyx1')
        print('State: %s    finish --> %s   %s' % (state,g,region))

        
    index+=1
    writer.save()
# Out:
# State:     finish --> female   United States
# State:     finish --> male   United States
# State:     finish --> both   United States
# State: 1    finish --> female   Alabama
# State: 1    finish --> male   Alabama
# State: 1    finish --> both   Alabama
# State: 2    finish --> female   Alaska
# State: 2    finish --> male   Alaska
# State: 2    finish --> both   Alaska
# State: 4    finish --> female   Arizona
# State: 4    finish --> male   Arizona
# State: 4    finish --> both   Arizona
# State: 5    finish --> female   Arkansas
# State: 5    finish --> male   Arkansas
# State: 5    finish --> both   Arkansas
# State: 6    finish --> female   California
# State: 6    finish --> male   California
# State: 6    finish --> both   California
# State: 8    finish --> female   Colorado
# State: 8    finish --> male   Colorado
# State: 8    finish --> both   Colorado
# State: 9    finish --> female   Connecticut
# State: 9    finish --> male   Connecticut
# State: 9    finish --> both   Connecticut
# State: 10    finish --> female   Delaware
# State: 10    finish --> male   Delaware
# State: 10    finish --> both   Delaware
# State: 11    finish --> female   D C
# State: 11    finish --> male   D C
# State: 11    finish --> both   D C
# State: 12    finish --> female   Florida
# State: 12    finish --> male   Florida
# State: 12    finish --> both   Florida
# State: 13    finish --> female   Georgia
# State: 13    finish --> male   Georgia
# State: 13    finish --> both   Georgia
# State: 15    finish --> female   Hawaii
# State: 15    finish --> male   Hawaii
# State: 15    finish --> both   Hawaii
# State: 16    finish --> female   Idaho
# State: 16    finish --> male   Idaho
# State: 16    finish --> both   Idaho
# State: 17    finish --> female   Illinois
# State: 17    finish --> male   Illinois
# State: 17    finish --> both   Illinois
# State: 18    finish --> female   Indiana
# State: 18    finish --> male   Indiana
# State: 18    finish --> both   Indiana
# State: 19    finish --> female   Iowa
# State: 19    finish --> male   Iowa
# State: 19    finish --> both   Iowa
# State: 20    finish --> female   Kansas
# State: 20    finish --> male   Kansas
# State: 20    finish --> both   Kansas
# State: 21    finish --> female   Kentucky
# State: 21    finish --> male   Kentucky
# State: 21    finish --> both   Kentucky
# State: 22    finish --> female   Louisiana
# State: 22    finish --> male   Louisiana
# State: 22    finish --> both   Louisiana
# State: 23    finish --> female   Maine
# State: 23    finish --> male   Maine
# State: 23    finish --> both   Maine
# State: 24    finish --> female   Maryland
# State: 24    finish --> male   Maryland
# State: 24    finish --> both   Maryland
# State: 25    finish --> female   Massachusetts
# State: 25    finish --> male   Massachusetts
# State: 25    finish --> both   Massachusetts
# State: 26    finish --> female   Michigan
# State: 26    finish --> male   Michigan
# State: 26    finish --> both   Michigan
# State: 27    finish --> female   Minnesota
# State: 27    finish --> male   Minnesota
# State: 27    finish --> both   Minnesota
# State: 28    finish --> female   Mississippi
# State: 28    finish --> male   Mississippi
# State: 28    finish --> both   Mississippi
# State: 29    finish --> female   Missouri
# State: 29    finish --> male   Missouri
# State: 29    finish --> both   Missouri
# State: 30    finish --> female   Montana
# State: 30    finish --> male   Montana
# State: 30    finish --> both   Montana
# State: 31    finish --> female   Nebraska
# State: 31    finish --> male   Nebraska
# State: 31    finish --> both   Nebraska
# State: 32    finish --> female   Nevada
# State: 32    finish --> male   Nevada
# State: 32    finish --> both   Nevada
# State: 33    finish --> female   New Hampshire
# State: 33    finish --> male   New Hampshire
# State: 33    finish --> both   New Hampshire
# State: 34    finish --> female   New Jersey
# State: 34    finish --> male   New Jersey
# State: 34    finish --> both   New Jersey
# State: 35    finish --> female   New Mexico
# State: 35    finish --> male   New Mexico
# State: 35    finish --> both   New Mexico
# State: 36    finish --> female   New York
# State: 36    finish --> male   New York
# State: 36    finish --> both   New York
# State: 37    finish --> female   North Carolina
# State: 37    finish --> male   North Carolina
# State: 37    finish --> both   North Carolina
# State: 38    finish --> female   North Dakota
# State: 38    finish --> male   North Dakota
# State: 38    finish --> both   North Dakota
# State: 39    finish --> female   Ohio
# State: 39    finish --> male   Ohio
# State: 39    finish --> both   Ohio
# State: 40    finish --> female   Oklahoma
# State: 40    finish --> male   Oklahoma
# State: 40    finish --> both   Oklahoma
# State: 41    finish --> female   Oregon
# State: 41    finish --> male   Oregon
# State: 41    finish --> both   Oregon
# State: 42    finish --> female   Pennsylvania
# State: 42    finish --> male   Pennsylvania
# State: 42    finish --> both   Pennsylvania
# State: 44    finish --> female   Rhode Island
# State: 44    finish --> male   Rhode Island
# State: 44    finish --> both   Rhode Island
# State: 45    finish --> female   South Carolina
# State: 45    finish --> male   South Carolina
# State: 45    finish --> both   South Carolina
# State: 46    finish --> female   South Dakota
# State: 46    finish --> male   South Dakota
# State: 46    finish --> both   South Dakota
# State: 47    finish --> female   Tennessee
# State: 47    finish --> male   Tennessee
# State: 47    finish --> both   Tennessee
# State: 48    finish --> female   Texas
# State: 48    finish --> male   Texas
# State: 48    finish --> both   Texas
# State: 49    finish --> female   Utah
# State: 49    finish --> male   Utah
# State: 49    finish --> both   Utah
# State: 50    finish --> female   Vermont
# State: 50    finish --> male   Vermont
# State: 50    finish --> both   Vermont
# State: 51    finish --> female   Virginia
# State: 51    finish --> male   Virginia
# State: 51    finish --> both   Virginia
# State: 53    finish --> female   Washington
# State: 53    finish --> male   Washington
# State: 53    finish --> both   Washington
# State: 54    finish --> female   West Virginia
# State: 54    finish --> male   West Virginia
# State: 54    finish --> both   West Virginia
# State: 55    finish --> female   Wisconsin
# State: 55    finish --> male   Wisconsin
# State: 55    finish --> both   Wisconsin
# State: 56    finish --> female   Wyoming
# State: 56    finish --> male   Wyoming
# State: 56    finish --> both   Wyoming

# %% [markdown]
# ## 4. Collect population data

# %%
gender =['male','female','both']

writer = pd.ExcelWriter(f'data/population.xlsx')    
g_index = 0
for g in gender:
    
    data = defaultdict(list)
    index = 0
    for region, _ in state_list.items():
        
        # change url to the table we want to collect data now
        state='' if region=='United States' else str(index)

        url = 'https://www.worldlifeexpectancy.com/j/state-gbd-cause-age?sel=d_35_44&sex=female&state={}'.format(state)  
        response = requests.get(url)
        html_doc = response.content 
        json_parsed = json.loads(html_doc)

        
        # avoid missing number in url, check whether url exists
        while (json_parsed['chart']['pops']['popitem'][g_index]['p'])=='0':
            index+=1
            state='' if region=='United States' else str(index)
            url = 'https://www.worldlifeexpectancy.com/j/state-gbd-cause-age?sel=d_35_44&sex=female&state={}'.format(state)  
            response = requests.get(url)
            html_doc = response.content 
            json_parsed = json.loads(html_doc)
                
        
        # put data into container
        tmp = json_parsed['chart']['pops']['popitem'][g_index]
        for i in tmp.keys():
            if i=='name':
                continue
            data[region].append(int(tmp[i].replace(',','')))
        index+=1 
        
        print('Gender: %s    finish --> %s' % (g,region))       
    

    # change format to panda Dataframe    
    frame = pd.DataFrame(data)  
    frame = frame.T
    frame.columns=["All", "0-14", "15-24", "25-34","35-44","45-54","55-64","65-74","75+"]
    g_index+=1    
    
    # write into file
    frame.to_excel(writer, sheet_name=g, index=True,engine='openpyx1')

writer.save()
# Out:
# Gender: male    finish --> United States
# Gender: male    finish --> Alabama
# Gender: male    finish --> Alaska
# Gender: male    finish --> Arizona
# Gender: male    finish --> Arkansas
# Gender: male    finish --> California
# Gender: male    finish --> Colorado
# Gender: male    finish --> Connecticut
# Gender: male    finish --> Delaware
# Gender: male    finish --> D C
# Gender: male    finish --> Florida
# Gender: male    finish --> Georgia
# Gender: male    finish --> Hawaii
# Gender: male    finish --> Idaho
# Gender: male    finish --> Illinois
# Gender: male    finish --> Indiana
# Gender: male    finish --> Iowa
# Gender: male    finish --> Kansas
# Gender: male    finish --> Kentucky
# Gender: male    finish --> Louisiana
# Gender: male    finish --> Maine
# Gender: male    finish --> Maryland
# Gender: male    finish --> Massachusetts
# Gender: male    finish --> Michigan
# Gender: male    finish --> Minnesota
# Gender: male    finish --> Mississippi
# Gender: male    finish --> Missouri
# Gender: male    finish --> Montana
# Gender: male    finish --> Nebraska
# Gender: male    finish --> Nevada
# Gender: male    finish --> New Hampshire
# Gender: male    finish --> New Jersey
# Gender: male    finish --> New Mexico
# Gender: male    finish --> New York
# Gender: male    finish --> North Carolina
# Gender: male    finish --> North Dakota
# Gender: male    finish --> Ohio
# Gender: male    finish --> Oklahoma
# Gender: male    finish --> Oregon
# Gender: male    finish --> Pennsylvania
# Gender: male    finish --> Rhode Island
# Gender: male    finish --> South Carolina
# Gender: male    finish --> South Dakota
# Gender: male    finish --> Tennessee
# Gender: male    finish --> Texas
# Gender: male    finish --> Utah
# Gender: male    finish --> Vermont
# Gender: male    finish --> Virginia
# Gender: male    finish --> Washington
# Gender: male    finish --> West Virginia
# Gender: male    finish --> Wisconsin
# Gender: male    finish --> Wyoming
# Gender: female    finish --> United States
# Gender: female    finish --> Alabama
# Gender: female    finish --> Alaska
# Gender: female    finish --> Arizona
# Gender: female    finish --> Arkansas
# Gender: female    finish --> California
# Gender: female    finish --> Colorado
# Gender: female    finish --> Connecticut
# Gender: female    finish --> Delaware
# Gender: female    finish --> D C
# Gender: female    finish --> Florida
# Gender: female    finish --> Georgia
# Gender: female    finish --> Hawaii
# Gender: female    finish --> Idaho
# Gender: female    finish --> Illinois
# Gender: female    finish --> Indiana
# Gender: female    finish --> Iowa
# Gender: female    finish --> Kansas
# Gender: female    finish --> Kentucky
# Gender: female    finish --> Louisiana
# Gender: female    finish --> Maine
# Gender: female    finish --> Maryland
# Gender: female    finish --> Massachusetts
# Gender: female    finish --> Michigan
# Gender: female    finish --> Minnesota
# Gender: female    finish --> Mississippi
# Gender: female    finish --> Missouri
# Gender: female    finish --> Montana
# Gender: female    finish --> Nebraska
# Gender: female    finish --> Nevada
# Gender: female    finish --> New Hampshire
# Gender: female    finish --> New Jersey
# Gender: female    finish --> New Mexico
# Gender: female    finish --> New York
# Gender: female    finish --> North Carolina
# Gender: female    finish --> North Dakota
# Gender: female    finish --> Ohio
# Gender: female    finish --> Oklahoma
# Gender: female    finish --> Oregon
# Gender: female    finish --> Pennsylvania
# Gender: female    finish --> Rhode Island
# Gender: female    finish --> South Carolina
# Gender: female    finish --> South Dakota
# Gender: female    finish --> Tennessee
# Gender: female    finish --> Texas
# Gender: female    finish --> Utah
# Gender: female    finish --> Vermont
# Gender: female    finish --> Virginia
# Gender: female    finish --> Washington
# Gender: female    finish --> West Virginia
# Gender: female    finish --> Wisconsin
# Gender: female    finish --> Wyoming
# Gender: both    finish --> United States
# Gender: both    finish --> Alabama
# Gender: both    finish --> Alaska
# Gender: both    finish --> Arizona
# Gender: both    finish --> Arkansas
# Gender: both    finish --> California
# Gender: both    finish --> Colorado
# Gender: both    finish --> Connecticut
# Gender: both    finish --> Delaware
# Gender: both    finish --> D C
# Gender: both    finish --> Florida
# Gender: both    finish --> Georgia
# Gender: both    finish --> Hawaii
# Gender: both    finish --> Idaho
# Gender: both    finish --> Illinois
# Gender: both    finish --> Indiana
# Gender: both    finish --> Iowa
# Gender: both    finish --> Kansas
# Gender: both    finish --> Kentucky
# Gender: both    finish --> Louisiana
# Gender: both    finish --> Maine
# Gender: both    finish --> Maryland
# Gender: both    finish --> Massachusetts
# Gender: both    finish --> Michigan
# Gender: both    finish --> Minnesota
# Gender: both    finish --> Mississippi
# Gender: both    finish --> Missouri
# Gender: both    finish --> Montana
# Gender: both    finish --> Nebraska
# Gender: both    finish --> Nevada
# Gender: both    finish --> New Hampshire
# Gender: both    finish --> New Jersey
# Gender: both    finish --> New Mexico
# Gender: both    finish --> New York
# Gender: both    finish --> North Carolina
# Gender: both    finish --> North Dakota
# Gender: both    finish --> Ohio
# Gender: both    finish --> Oklahoma
# Gender: both    finish --> Oregon
# Gender: both    finish --> Pennsylvania
# Gender: both    finish --> Rhode Island
# Gender: both    finish --> South Carolina
# Gender: both    finish --> South Dakota
# Gender: both    finish --> Tennessee
# Gender: both    finish --> Texas
# Gender: both    finish --> Utah
# Gender: both    finish --> Vermont
# Gender: both    finish --> Virginia
# Gender: both    finish --> Washington
# Gender: both    finish --> West Virginia
# Gender: both    finish --> Wisconsin
# Gender: both    finish --> Wyoming
